# %%
import numpy as np
import matplotlib.pyplot as plt
from networkx.drawing.nx_agraph import graphviz_layout

# %%
from ADFRegressor import Regressor1ADF 
from GPIndividuals import *

from LowLevel import *           # where low-level primitives are defined

from GPUtils import *            # Selection (binary tournament, roulette wheel, elite selection) and migration methods
from Utils import *              # other optional functions

# %%
lowlevel = ['ADD', 'SUB', 'MUL']
Node.f1_set=lowlevel
Node.i2_set=[1.0,1.0]

# %%
parent1 = Regressor1ADF(input_vector_size = 2, 
                        adf_arity =2, 
                        complexity = 3, 
                        adf_complexity = 3)

# %%
plt.figure(figsize=(4,4))
graph, labels, color_map = get_graph(parent1.trees[0])
nx.draw(graph, pos=nx.nx_agraph.graphviz_layout(graph.reverse(), prog="dot"), with_labels=True, labels=labels, node_size=1200, node_color=color_map)

# %%
plt.figure(figsize=(4,4))
graph, labels, color_map = get_graph(parent1.trees[1])
nx.draw(graph, pos=nx.nx_agraph.graphviz_layout(graph.reverse(), prog="dot"), with_labels=True, labels=labels, node_size=1200, node_color=color_map)

# %%
main_tree_nodes = parent1.trees[0].count_nodes_type()

# %%
main_tree_nodes['total']

# %%
adf_tree_nodes = parent1.trees[1].count_nodes_type()

# %%
adf_tree_nodes['total']

# %%
parent1.predict([2,3])

# %%
parent2 = Regressor1ADF(input_vector_size = 2, 
                        adf_arity =2, 
                        complexity = 3, 
                        adf_complexity = 3)

# %%
plt.figure(figsize=(4,4))
graph, labels, color_map = get_graph(parent2.trees[0])
nx.draw(graph, pos=nx.nx_agraph.graphviz_layout(graph.reverse(), prog="dot"), with_labels=True, labels=labels, node_size=1200, node_color=color_map)

# %%
plt.figure(figsize=(4,4))
graph, labels, color_map = get_graph(parent2.trees[1])
nx.draw(graph, pos=nx.nx_agraph.graphviz_layout(graph.reverse(), prog="dot"), with_labels=True, labels=labels, node_size=1200, node_color=color_map)

# %%
parent2.predict([2,3])

# %%
off1, off2 = Regressor1ADF.protected_crossover(parent1, parent2)

# %%
plt.figure(figsize=(4,4))
graph, labels, color_map = get_graph(off1.trees[0])
nx.draw(graph, pos=nx.nx_agraph.graphviz_layout(graph.reverse(), prog="dot"), with_labels=True, labels=labels, node_size=1200, node_color=color_map)

# %%
plt.figure(figsize=(4,4))
graph, labels, color_map = get_graph(off1.trees[1])
nx.draw(graph, pos=nx.nx_agraph.graphviz_layout(graph.reverse(), prog="dot"), with_labels=True, labels=labels, node_size=1200, node_color=color_map)

# %%
off1.predict([2,3])

# %%
plt.figure(figsize=(4,4))
graph, labels, color_map = get_graph(off2.trees[0])
nx.draw(graph, pos=nx.nx_agraph.graphviz_layout(graph.reverse(), prog="dot"), with_labels=True, labels=labels, node_size=1200, node_color=color_map)

# %%
plt.figure(figsize=(4,4))
graph, labels, color_map = get_graph(off2.trees[1])
nx.draw(graph, pos=nx.nx_agraph.graphviz_layout(graph.reverse(), prog="dot"), with_labels=True, labels=labels, node_size=1200, node_color=color_map)

# %%
off2.predict([2,3])

# %%
off3, off4 = Regressor1ADF.protected_crossover(off1, off2)

# %%
off3.predict([2,3])

# %%
off4.predict([2,3])

# %%
off5, off6 = Regressor1ADF.protected_crossover(off3, off4)

# %%
off5.predict([2,3])

# %%
off6.predict([2,3])

# %%
parent1.trees[0].nodes
