# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from Utils import *

# %%
# Define the CSV file path
csv_file = 'data.csv'

# %%
# Now you can load the CSV into a DataFrame later
df = pd.read_csv(csv_file)

# %%
print(df)
# Out:
#      Generations  Max Tree Depth  Population Size       MSE
# 0            120               6              400  0.007795
# 1            120               6              400  0.006999
# 2            120               6              400  0.008812
# 3            120               6              400  0.008515
# 4            120               6              400  0.011139
# ..           ...             ...              ...       ...
# 347          240               9             2400  0.007206
# 348          240               9             2400  0.006041
# 349          240               9             2400  0.007111
# 350          240               9             2400  0.006803
# 351          240               9             2400  0.008041
#
# [352 rows x 4 columns]

# %%
df1 = df[df['Max Tree Depth'] != 9]

# %%
df1
# Out:
#      Generations  Max Tree Depth  Population Size       MSE
# 0            120               6              400  0.007795
# 1            120               6              400  0.006999
# 2            120               6              400  0.008812
# 3            120               6              400  0.008515
# 4            120               6              400  0.011139
# ..           ...             ...              ...       ...
# 171          240               6             2400  0.005463
# 172          240               6             2400  0.005760
# 173          240               6             2400  0.006710
# 174          240               6             2400  0.005819
# 175          240               6             2400  0.005382
#
# [176 rows x 4 columns]

# %%
sns.set_theme(style="whitegrid", palette="pastel")

# %%
ax = sns.boxplot(x="Population Size", y="MSE",
            hue="Generations", palette=["m", "g"],
            data=df1)
ax.set(ylim=(0.004, .035))
# Out:
# [(0.004, 0.035)]

# %%
df2 = df[df['Max Tree Depth'] != 6]

# %%
sns.set_theme(style="whitegrid", palette="pastel")
ax = sns.boxplot(x="Population Size", y="MSE",
                 hue="Generations", palette=["m", "g"],
                 data=df2)
#sns.despine(offset=10, trim=True)
ax.set(ylim=(0.004, .035))
# Out:
# [(0.004, 0.035)]
